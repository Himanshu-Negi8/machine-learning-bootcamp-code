# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(2,20,1000)

# %%
m,c = 2,10

# %%
y = m*x+c

# %%
plt.scatter(x,y)

# %%
noise = np.random.randn(1000)*5

# %%
y_modified = y+noise

# %%
plt.scatter(x,y_modified)

# %%
x = np.random.randn(10000)

# %%
out = plt.hist(x,bins=120)
#bins are number of towers

# %%
temp = np.random.randint(-4,4,1000)

# %%
out = plt.hist(temp,bins=120)

# %%
out = plt.pie([10,20,30],explode=[0,.1,0], shadow=True , radius =1)

# %%
import seaborn as sns

# %%
x = np.random.randn(1000)

# %%
plt.figure(figsize=(4,4))
sns.distplot(x,bins=30,kde=False,rug=True)

# %%
data = sns.load_dataset("tips")

# %%
sns.scatterplot(data["total_bill"], data["tip"])

# %%
sns.scatterplot(data["total_bill"], data["tip"], hue=data["smoker"])

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
random_data = sns.load_dataset("planets")

# %%
random_data
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.scatterplot(random_data["mass"], random_data["orbital_period"], hue=random_data["mass"])

# %%
data["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sns.violinplot(y=data.total_bill)

# %%
from sklearn.datasets import load_boston

# %%
X,y = load_boston(return_X_y=True)

# %%
sns.violinplot(y=y)
