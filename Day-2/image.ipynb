# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil =Image.open("thor.jpg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (1065, 1600, 3)

# %%
plt.imshow(arr)

# %%
cut = arr[70:400,700:1000]

# %%
plt.imshow(cut)

# %%
obj = arr.copy()

# %%
obj[:,:,[1,2]]=0

# %%
plt.imshow(obj)

# %%
grey = arr.mean(axis=2)

# %%
plt.imshow(grey,cmap="gray")
#cmap stands for color map
